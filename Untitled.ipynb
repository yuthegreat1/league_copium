# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Vincent excels in the early game
# who makes the most impact in terms of winning the game, who makes the least

# %%
league_data = pd.read_csv("Resources/output.csv")
league_data.head()
# Out:
#     gameCreation  gameDuration  gameEndTimestamp      gameId gameMode  \
# 0  1659243293411          3083     1659246408695  4390836827  CLASSIC
# 1  1652239013000          2269     1652241311788  4303562603  CLASSIC
# 2  1664071720788          1219     1664072977137  4445981233  CLASSIC
# 3  1665822111888          1862     1665824030079  4465276217  CLASSIC
# 4  1657942732000          1717     1657944481539  4374926995  CLASSIC
#
#                        gameName  gameStartTimestamp      gameType  \
# 0  teambuilder-match-4390836827       1659243324670  MATCHED_GAME
# 1  teambuilder-match-4303562603       1652239041998  MATCHED_GAME
# 2  teambuilder-match-4445981233       1664071757431  MATCHED_GAME
# 3  teambuilder-match-4465276217       1665822167917  MATCHED_GAME
# 4  teambuilder-match-4374926995       1657942763936  MATCHED_GAME
#
#       gameVersion  mapId  ...  takedownsFirst25Minutes_RyGuyL  \
# 0  12.14.456.5556     11  ...                             NaN
# ...

# %%
league_keys = league_data.keys()
league_keys[:30]
# Out:
# Index(['gameCreation', 'gameDuration', 'gameEndTimestamp', 'gameId',
#        'gameMode', 'gameName', 'gameStartTimestamp', 'gameType', 'gameVersion',
#        'mapId', 'assists_Aitori', 'baronKills_Aitori', 'basicPings_Aitori',
#        'bountyLevel_Aitori', '12AssistStreakCount_Aitori',
#        'abilityUses_Aitori', 'acesBefore15Minutes_Aitori',
#        'alliedJungleMonsterKills_Aitori', 'baronTakedowns_Aitori',
#        'blastConeOppositeOpponentCount_Aitori', 'bountyGold_Aitori',
#        'buffsStolen_Aitori', 'completeSupportQuestInTime_Aitori',
#        'controlWardsPlaced_Aitori', 'damagePerMinute_Aitori',
#        'damageTakenOnTeamPercentage_Aitori', 'dancedWithRiftHerald_Aitori',
#        'deathsByEnemyChamps_Aitori', 'dodgeSkillShotsSmallWindow_Aitori',
#        'doubleAces_Aitori'],
#       dtype='object')

# %%
names = ["Aitori","RyGuyL","Dracotron", "IrenehCp", "BitFish" ]
aitori_list = []
ryguyl_list = []
dracotron_list = []
irenehcp_list = []
bitfish_list = []
game_list = []
for key in league_keys:
    nameless_key = True
    for name in names:
        if name in key and name == "Aitori":
            aitori_list.append(key)
            nameless_key = False
        if name in key and name == "RyGuyL":
            ryguyl_list.append(key)
            nameless_key = False
        if name in key and name == "Dracotron":
            dracotron_list.append(key)
            nameless_key = False
        if name in key and name == "IrenehCp":
            irenehcp_list.append(key)
            nameless_key = False
        if name in key and name == "BitFish":
            bitfish_list.append(key)
            nameless_key = False
    if nameless_key == True:
        game_list.append(key)
            #for all the names if non of them are in the key, add it to game list

# %%
aitori_list
# Out:
# ['assists_Aitori',
#  'baronKills_Aitori',
#  'basicPings_Aitori',
#  'bountyLevel_Aitori',
#  '12AssistStreakCount_Aitori',
#  'abilityUses_Aitori',
#  'acesBefore15Minutes_Aitori',
#  'alliedJungleMonsterKills_Aitori',
#  'baronTakedowns_Aitori',
#  'blastConeOppositeOpponentCount_Aitori',
#  'bountyGold_Aitori',
#  'buffsStolen_Aitori',
#  'completeSupportQuestInTime_Aitori',
#  'controlWardsPlaced_Aitori',
#  'damagePerMinute_Aitori',
#  'damageTakenOnTeamPercentage_Aitori',
#  'dancedWithRiftHerald_Aitori',
#  'deathsByEnemyChamps_Aitori',
#  'dodgeSkillShotsSmallWindow_Aitori',
#  'doubleAces_Aitori',
#  'dragonTakedowns_Aitori',
#  'earliestBaron_Aitori',
#  'earlyLaningPhaseGoldExpAdvantage_Aitori',
#  'effectiveHealAndShielding_Aitori',
#  'elderDragonKillsWithOpposingSoul_Aitori',
#  'elderDragonMultikills_Aitori',
#  'enemyChampionImmobilizations_Aitori',
#  'enemyJungleMonsterKills_Aitori',
#  'epicMonsterKillsNearEnemyJungler_Aitori',
# ...
